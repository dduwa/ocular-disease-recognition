# %% [markdown]
# # Imports

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

from PIL import Image

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# %% [markdown]
# # Preparing the Data

# %%
# Load the CSV files
df_augmented= pd.read_csv('dataset/csvs/augmented.csv')
test_df = pd.read_csv('dataset/csvs/test_df.csv')
val_df = pd.read_csv('dataset/csvs/val_df.csv')

# %%
def file_exists(file_paths):
    # Filter out non-existing files
    return [file_path for file_path in file_paths if os.path.exists(file_path)]

def load_and_prepare_dataset(df, images_dir, shuffle=True, batch_size=32):
    images_left = images_dir + df['Left-Fundus']
    images_right = images_dir + df['Right-Fundus']

    labels_left = df['target'].values
    labels_right = df['target'].values

    # Combine the left and right images and labels
    filenames = np.concatenate([images_left, images_right])
    labels = np.concatenate([labels_left, labels_right])

    # Filter out filenames that do not exist
    valid_filenames = file_exists(filenames)
    valid_labels = labels[np.isin(filenames, valid_filenames)]  # Keep labels corresponding to the valid filenames

    # Creating TensorFlow dataset
    dataset = tf.data.Dataset.from_tensor_slices((valid_filenames, valid_labels))
    dataset = dataset.map(parse_image_and_label)  # Apply the preprocessing function
    if shuffle:
        dataset = dataset.shuffle(buffer_size=len(valid_filenames))
    dataset = dataset.batch(batch_size)
    return dataset

def parse_image_and_label(image_path, label_string):
    image = tf.io.read_file(image_path)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, [224, 224])
    image = tf.cast(image, tf.float32)
    image = tf.keras.applications.vgg16.preprocess_input(image)
    label = tf.strings.substr(label_string, 1, tf.strings.length(label_string) - 2)
    label = tf.strings.to_number(tf.strings.split(label, ','), out_type=tf.float32)
    return image, label

# %%
def load_and_prepare_aug_dataset(df, images_dir, shuffle=True, batch_size=32):
    # Concatenate the directory with filenames to get the full image paths
    images = images_dir + df['filename'].astype(str)
    
    # Convert labels to the correct format if they are not already (e.g., one-hot encoding)
    # This step depends on how your labels are formatted and what your model expects
    labels = df['target'].values
    
    # Create TensorFlow dataset
    dataset = tf.data.Dataset.from_tensor_slices((images, labels))
    dataset = dataset.map(parse_image_and_label, num_parallel_calls=tf.data.AUTOTUNE)
    
    if shuffle:
        dataset = dataset.shuffle(buffer_size=len(df))
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)  # Prefetch data for performance
    
    return dataset
df_augmented['target'] = df_augmented['target'].apply(lambda x: str(x))

# %%
train_ds = load_and_prepare_aug_dataset(df_augmented, 'dataset/augmented/', shuffle=True, batch_size=32)
val_ds = load_and_prepare_dataset(val_df, 'dataset/preprocessed_images/', shuffle=True, batch_size=32)
test_ds = load_and_prepare_dataset(test_df, 'dataset/preprocessed_images/', shuffle=False, batch_size=32)

# %%
print("size of training dataset: ", train_ds.cardinality().numpy())
print("size of validation dataset: ", val_ds.cardinality().numpy())
print("size of test dataset: ", test_ds.cardinality().numpy())
# Out:
# size of training dataset:  272
# size of validation dataset:  63
# size of test dataset:  78

# %% [markdown]
# # Loading and Visualising the Training Data

# %%
print("Training dataset")
for images, labels in train_ds.take(1):
    print(images.shape)
    print(labels.shape)
# Plotting the first 9 images
plt.figure(figsize=(10, 10))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    class_names = ['Normal', 'Diabetes', 'Glaucoma', 'Cataract', 'AMD', 'Hypertension', 'Myopia', 'Other']
    class_index = np.argmax(labels[i].numpy())
    plt.title(class_names[class_index])

    plt.axis("off")
# Out:
# Training dataset
# (32, 224, 224, 3)
# (32, 8)

# %%
print("Validation dataset")
for images, labels in val_ds.take(1):
    print(images.shape)
    print(labels.shape)
# Plotting the first 9 images
plt.figure(figsize=(10, 10))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    class_names = ['Normal', 'Diabetes', 'Glaucoma', 'Cataract', 'AMD', 'Hypertension', 'Myopia', 'Other']
    class_index = np.argmax(labels[i].numpy())
    plt.title(class_names[class_index])
    plt.axis("off")
# Out:
# Validation dataset
# (32, 224, 224, 3)
# (32, 8)

# %%
# Calculate class weights
def get_class_weights(labels):
    total_samples = len(labels)
    n_classes = len(labels[0])
    class_counts = np.zeros(n_classes)
    for label in labels:
        class_counts += label
    class_weights = total_samples / (n_classes * class_counts)
    return class_weights

# Get the labels from the training dataset
train_labels = []
for _, labels in train_ds:
    train_labels.append(labels.numpy())
train_labels = np.concatenate(train_labels)

# Calculate class weights
class_weights = get_class_weights(train_labels)
print("Class weights:", class_weights)

# Assuming class_weights is the array returned by your function
class_weights_array = get_class_weights(train_labels)

# Convert this array into a dictionary
class_weights_dict = {i: weight for i, weight in enumerate(class_weights_array)}

print("Class weights dictionary:", class_weights_dict)

# %% [markdown]
# # Training the model
#
# - A BatchNormalization layer and a Dropout layer are added immediately after flattening the output of the pretrained ResNet50 base. A Dense layer with both L1 and L2 regularization follows the Dropout layer. The regularization helps prevent overfitting by adding a penalty for larger weights, and Dropout randomly sets input units to 0 with a frequency of rate at each step during training time, which helps prevent overfitting. Batch Normalization normalizes the inputs heading into the next layer, which ensures that the network always creates activations with the same distribution that we desire.

# %%
# Setup callbacks
checkpoint = ModelCheckpoint(filepath='best_model_VGG16_v2.h5', verbose=1, save_best_only=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-7, verbose=1) # increased patience from 3 to 5 and factor from 0.2 to 0.5
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True) # increased from 5 to 10


callbacks = [early_stopping, checkpoint, reduce_lr]

# %%
from keras.layers import Dropout, BatchNormalization, Activation
from keras.models import Model

# %%
pretrained_model = tf.keras.applications.VGG16(
    include_top=False,
    input_shape=(224, 224, 3),
    pooling='avg', classes=8,
    weights='imagenet')

for layer in pretrained_model.layers:
    layer.trainable = False
    
vgg_16_model = Sequential()

    
vgg_16_model.add(pretrained_model)
vgg_16_model.add(Flatten())
vgg_16_model.add(Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.0001)))
vgg_16_model.add(Dropout(0.5))
vgg_16_model.add(Dense(8, activation='softmax'))

# %%
vgg_16_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 512)               14714688
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 256)               131328
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 8)                 2056
#
# =================================================================
# Total params: 14,848,072
# Trainable params: 133,384
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
vgg_16_model.compile(optimizer=Adam(learning_rate=0.00001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
epochs =  50
history = vgg_16_model.fit(train_ds, validation_data=val_ds, epochs=epochs, callbacks=callbacks, class_weights=class_weights_dict)
# Out:
# Epoch 1/50
# 272/272 [==============================] - ETA: 0s - loss: 5.9435 - accuracy: 0.1223
# Epoch 1: val_loss improved from inf to 2.85645, saving model to best_model_VGG16_v2.h5
# 272/272 [==============================] - 69s 212ms/step - loss: 5.9435 - accuracy: 0.1223 - val_loss: 2.8565 - val_accuracy: 0.1428 - lr: 1.0000e-05
# Epoch 2/50
# 272/272 [==============================] - ETA: 0s - loss: 4.8086 - accuracy: 0.1684
# Epoch 2: val_loss improved from 2.85645 to 2.64848, saving model to best_model_VGG16_v2.h5
# 272/272 [==============================] - 61s 203ms/step - loss: 4.8086 - accuracy: 0.1684 - val_loss: 2.6485 - val_accuracy: 0.1785 - lr: 1.0000e-05
# Epoch 3/50
# 272/272 [==============================] - ETA: 0s - loss: 4.0672 - accuracy: 0.2075
# Epoch 3: val_loss improved from 2.64848 to 2.51528, saving model to best_model_VGG16_v2.h5
# 272/272 [==============================] - 61s 205ms/step - loss: 4.0672 - accuracy: 0.2075 - val_loss: 2.5153 - val_accuracy: 0.2031 - lr: 1.0000e-05
# Epoch 4/50
# 272/272 [==============================] - ETA: 0s - loss: 3.4862 - accuracy: 0.2491
# Epoch 4: val_loss improved from 2.51528 to 2.40031, saving model to best_model_VGG16_v2.h5
# 272/272 [==============================] - 61s 207ms/step - loss: 3.4862 - accuracy: 0.2491 - val_loss: 2.4003 - val_accuracy: 0.2167 - lr: 1.0000e-05
# Epoch 5/50
# 272/272 [==============================] - ETA: 0s - loss: 3.0677 - accuracy: 0.2690
# Epoch 5: val_loss improved from 2.40031 to 2.27284, saving model to best_model_VGG16_v2.h5
# 272/272 [==============================] - 62s 209ms/step - loss: 3.0677 - accuracy: 0.2690 - val_loss: 2.2728 - val_accuracy: 0.2318 - lr: 1.0000e-05
# Epoch 6/50
# 272/272 [==============================] - ETA: 0s - loss: 2.7709 - accuracy: 0.2946
# Epoch 6: val_loss improved from 2.27284 to 2.20719, saving model to best_model_VGG16_v2.h5
# 272/272 [==============================] - 62s 209ms/step - loss: 2.7709 - accuracy: 0.2946 - val_loss: 2.2072 - val_accuracy: 0.2383 - lr: 1.0000e-05
# Epoch 7/50
# 272/272 [==============================] - ETA: 0s - loss: 2.4714 - accuracy: 0.3150
# Epoch 7: val_loss improved from 2.20719 to 2.13271, saving model to best_model_VGG16_v2.h5
# 272/272 [==============================] - 63s 210ms/step - loss: 2.4714 - accuracy: 0.3150 - val_loss: 2.1327 - val_accuracy: 0.2474 - lr: 1.0000e-05
# Epoch 8/50
# 272/272 [==============================] - ETA: 0s - loss: 2.2943 - accuracy: 0.3267
# Epoch 8: val_loss improved from 2.13271 to 2.07081, saving model to best_model_VGG16_v2.h5
# 272/272 [==============================] - 63s 211ms/step - loss: 2.2943 - accuracy: 0.3267 - val_loss: 2.0708 - val_accuracy: 0.2579 - lr: 1.0000e-05
# Epoch 9/50
# 272/272 [==============================] - ETA: 0s - loss: 2.1089 - accuracy: 0.3398
# Epoch 9: val_loss improved from 2.07081 to 2.02749, saving model to best_model_VGG16_v2.h5
# 272/272 [==============================] - 63s 211ms/step - loss: 2.1089 - accuracy: 0.3398 - val_loss: 2.0275 - val_accuracy: 0.2609 - lr: 1.0000e-05
# Epoch 10/50
# 272/272 [==============================] - ETA: 0s - loss: 1.9970 - accuracy: 0.3558
# Epoch 10: val_loss improved from 2.02749 to 1.99827, saving model to best_model_VGG16_v2.h5
# 272/272 [==============================] - 63s 211ms/step - loss: 1.9970 - accuracy: 0.3558 - val_loss: 1.9983 - val_accuracy: 0.2650 - lr: 1.0000e-05
# Epoch 11/50
# 272/272 [==============================] - ETA: 0s - loss: 1.8935 - accuracy: 0.3767
# Epoch 11: val_loss improved from 1.99827 to 1.95268, saving model to best_model_VGG16_v2.h5
# 272/272 [==============================] - 64s 214ms/step - loss: 1.8935 - accuracy: 0.3767 - val_loss: 1.9527 - val_accuracy: 0.2745 - lr: 1.0000e-05
# Epoch 12/50
# 272/272 [==============================] - ETA: 0s - loss: 1.8236 - accuracy: 0.3749
# Epoch 12: val_loss improved from 1.95268 to 1.93800, saving model to best_model_VGG16_v2.h5
# 272/272 [==============================] - 64s 213ms/step - loss: 1.8236 - accuracy: 0.3749 - val_loss: 1.9380 - val_accuracy: 0.2821 - lr: 1.0000e-05
# Epoch 13/50
# 272/272 [==============================] - ETA: 0s - loss: 1.7715 - accuracy: 0.3872
# Epoch 13: val_loss improved from 1.93800 to 1.90068, saving model to best_model_VGG16_v2.h5
# 272/272 [==============================] - 63s 212ms/step - loss: 1.7715 - accuracy: 0.3872 - val_loss: 1.9007 - val_accuracy: 0.2841 - lr: 1.0000e-05
# Epoch 14/50
# 272/272 [==============================] - ETA: 0s - loss: 1.7187 - accuracy: 0.3977
# Epoch 14: val_loss improved from 1.90068 to 1.90011, saving model to best_model_VGG16_v2.h5
# 272/272 [==============================] - 63s 213ms/step - loss: 1.7187 - accuracy: 0.3977 - val_loss: 1.9001 - val_accuracy: 0.2826 - lr: 1.0000e-05
# Epoch 15/50
# 272/272 [==============================] - ETA: 0s - loss: 1.6857 - accuracy: 0.4009
# Epoch 15: val_loss improved from 1.90011 to 1.86970, saving model to best_model_VGG16_v2.h5
# 272/272 [==============================] - 63s 212ms/step - loss: 1.6857 - accuracy: 0.4009 - val_loss: 1.8697 - val_accuracy: 0.2961 - lr: 1.0000e-05
# Epoch 16/50
# 272/272 [==============================] - ETA: 0s - loss: 1.6517 - accuracy: 0.4090
# Epoch 16: val_loss did not improve from 1.86970
# 272/272 [==============================] - 64s 214ms/step - loss: 1.6517 - accuracy: 0.4090 - val_loss: 1.8707 - val_accuracy: 0.2951 - lr: 1.0000e-05
# Epoch 17/50
# 272/272 [==============================] - ETA: 0s - loss: 1.6209 - accuracy: 0.4104
# Epoch 17: val_loss improved from 1.86970 to 1.85965, saving model to best_model_VGG16_v2.h5
# 272/272 [==============================] - 64s 213ms/step - loss: 1.6209 - accuracy: 0.4104 - val_loss: 1.8597 - val_accuracy: 0.2921 - lr: 1.0000e-05
# Epoch 18/50
# 272/272 [==============================] - ETA: 0s - loss: 1.5957 - accuracy: 0.4214
# Epoch 18: val_loss improved from 1.85965 to 1.84973, saving model to best_model_VGG16_v2.h5
# 272/272 [==============================] - 64s 214ms/step - loss: 1.5957 - accuracy: 0.4214 - val_loss: 1.8497 - val_accuracy: 0.2961 - lr: 1.0000e-05
# Epoch 19/50
# 272/272 [==============================] - ETA: 0s - loss: 1.5666 - accuracy: 0.4313
# Epoch 19: val_loss improved from 1.84973 to 1.82958, saving model to best_model_VGG16_v2.h5
# 272/272 [==============================] - 64s 213ms/step - loss: 1.5666 - accuracy: 0.4313 - val_loss: 1.8296 - val_accuracy: 0.3027 - lr: 1.0000e-05
# Epoch 20/50
# 272/272 [==============================] - ETA: 0s - loss: 1.5506 - accuracy: 0.4397
# Epoch 20: val_loss improved from 1.82958 to 1.82251, saving model to best_model_VGG16_v2.h5
# 272/272 [==============================] - 64s 213ms/step - loss: 1.5506 - accuracy: 0.4397 - val_loss: 1.8225 - val_accuracy: 0.3022 - lr: 1.0000e-05
# Epoch 21/50
# 272/272 [==============================] - ETA: 0s - loss: 1.5270 - accuracy: 0.4427
# Epoch 21: val_loss improved from 1.82251 to 1.81774, saving model to best_model_VGG16_v2.h5
# 272/272 [==============================] - 64s 213ms/step - loss: 1.5270 - accuracy: 0.4427 - val_loss: 1.8177 - val_accuracy: 0.3047 - lr: 1.0000e-05
# Epoch 22/50
# 272/272 [==============================] - ETA: 0s - loss: 1.5256 - accuracy: 0.4377
# Epoch 22: val_loss improved from 1.81774 to 1.81262, saving model to best_model_VGG16_v2.h5
# 272/272 [==============================] - 64s 213ms/step - loss: 1.5256 - accuracy: 0.4377 - val_loss: 1.8126 - val_accuracy: 0.3042 - lr: 1.0000e-05
# Epoch 23/50
# 272/272 [==============================] - ETA: 0s - loss: 1.5009 - accuracy: 0.4516
# Epoch 23: val_loss improved from 1.81262 to 1.79004, saving model to best_model_VGG16_v2.h5
# 272/272 [==============================] - 64s 213ms/step - loss: 1.5009 - accuracy: 0.4516 - val_loss: 1.7900 - val_accuracy: 0.3218 - lr: 1.0000e-05
# Epoch 24/50
# 272/272 [==============================] - ETA: 0s - loss: 1.4866 - accuracy: 0.4595
# Epoch 24: val_loss did not improve from 1.79004
# 272/272 [==============================] - 65s 217ms/step - loss: 1.4866 - accuracy: 0.4595 - val_loss: 1.7930 - val_accuracy: 0.3112 - lr: 1.0000e-05
# Epoch 25/50
# 272/272 [==============================] - ETA: 0s - loss: 1.4637 - accuracy: 0.4577
# Epoch 25: val_loss improved from 1.79004 to 1.78573, saving model to best_model_VGG16_v2.h5
# 272/272 [==============================] - 65s 215ms/step - loss: 1.4637 - accuracy: 0.4577 - val_loss: 1.7857 - val_accuracy: 0.3082 - lr: 1.0000e-05
# Epoch 26/50
# 272/272 [==============================] - ETA: 0s - loss: 1.4496 - accuracy: 0.4721
# Epoch 26: val_loss improved from 1.78573 to 1.77388, saving model to best_model_VGG16_v2.h5
# 272/272 [==============================] - 66s 217ms/step - loss: 1.4496 - accuracy: 0.4721 - val_loss: 1.7739 - val_accuracy: 0.3157 - lr: 1.0000e-05
# Epoch 27/50
# 272/272 [==============================] - ETA: 0s - loss: 1.4465 - accuracy: 0.4744
# Epoch 27: val_loss improved from 1.77388 to 1.77275, saving model to best_model_VGG16_v2.h5
# 272/272 [==============================] - 65s 218ms/step - loss: 1.4465 - accuracy: 0.4744 - val_loss: 1.7728 - val_accuracy: 0.3152 - lr: 1.0000e-05
# Epoch 28/50
# 272/272 [==============================] - ETA: 0s - loss: 1.4282 - accuracy: 0.4756
# Epoch 28: val_loss improved from 1.77275 to 1.76610, saving model to best_model_VGG16_v2.h5
# 272/272 [==============================] - 66s 215ms/step - loss: 1.4282 - accuracy: 0.4756 - val_loss: 1.7661 - val_accuracy: 0.3233 - lr: 1.0000e-05
# Epoch 29/50
# 272/272 [==============================] - ETA: 0s - loss: 1.4156 - accuracy: 0.4852
# Epoch 29: val_loss improved from 1.76610 to 1.74953, saving model to best_model_VGG16_v2.h5
# 272/272 [==============================] - 64s 215ms/step - loss: 1.4156 - accuracy: 0.4852 - val_loss: 1.7495 - val_accuracy: 0.3263 - lr: 1.0000e-05
# Epoch 30/50
# 272/272 [==============================] - ETA: 0s - loss: 1.3939 - accuracy: 0.4922
# Epoch 30: val_loss did not improve from 1.74953
# 272/272 [==============================] - 65s 216ms/step - loss: 1.3939 - accuracy: 0.4922 - val_loss: 1.7555 - val_accuracy: 0.3177 - lr: 1.0000e-05
# Epoch 31/50
# 272/272 [==============================] - ETA: 0s - loss: 1.3843 - accuracy: 0.4970
# Epoch 31: val_loss did not improve from 1.74953
# 272/272 [==============================] - 66s 218ms/step - loss: 1.3843 - accuracy: 0.4970 - val_loss: 1.7508 - val_accuracy: 0.3157 - lr: 1.0000e-05
# Epoch 32/50
# 272/272 [==============================] - ETA: 0s - loss: 1.3797 - accuracy: 0.4951
# Epoch 32: val_loss improved from 1.74953 to 1.74606, saving model to best_model_VGG16_v2.h5
# 272/272 [==============================] - 66s 218ms/step - loss: 1.3797 - accuracy: 0.4951 - val_loss: 1.7461 - val_accuracy: 0.3303 - lr: 1.0000e-05
# Epoch 33/50
# 272/272 [==============================] - ETA: 0s - loss: 1.3652 - accuracy: 0.5022
# Epoch 33: val_loss improved from 1.74606 to 1.73569, saving model to best_model_VGG16_v2.h5
# 272/272 [==============================] - 66s 218ms/step - loss: 1.3652 - accuracy: 0.5022 - val_loss: 1.7357 - val_accuracy: 0.3308 - lr: 1.0000e-05
# Epoch 34/50
# 272/272 [==============================] - ETA: 0s - loss: 1.3442 - accuracy: 0.5153
# Epoch 34: val_loss did not improve from 1.73569
# 272/272 [==============================] - 67s 220ms/step - loss: 1.3442 - accuracy: 0.5153 - val_loss: 1.7405 - val_accuracy: 0.3273 - lr: 1.0000e-05
# Epoch 35/50
# 272/272 [==============================] - ETA: 0s - loss: 1.3429 - accuracy: 0.5117
# Epoch 35: val_loss improved from 1.73569 to 1.71610, saving model to best_model_VGG16_v2.h5
# 272/272 [==============================] - 66s 219ms/step - loss: 1.3429 - accuracy: 0.5117 - val_loss: 1.7161 - val_accuracy: 0.3424 - lr: 1.0000e-05
# Epoch 36/50
# 272/272 [==============================] - ETA: 0s - loss: 1.3236 - accuracy: 0.5157
# Epoch 36: val_loss improved from 1.71610 to 1.70883, saving model to best_model_VGG16_v2.h5
# 272/272 [==============================] - 66s 218ms/step - loss: 1.3236 - accuracy: 0.5157 - val_loss: 1.7088 - val_accuracy: 0.3434 - lr: 1.0000e-05
# Epoch 37/50
# 272/272 [==============================] - ETA: 0s - loss: 1.3251 - accuracy: 0.5075
# Epoch 37: val_loss improved from 1.70883 to 1.70230, saving model to best_model_VGG16_v2.h5
# 272/272 [==============================] - 66s 217ms/step - loss: 1.3251 - accuracy: 0.5075 - val_loss: 1.7023 - val_accuracy: 0.3419 - lr: 1.0000e-05
# Epoch 38/50
# 272/272 [==============================] - ETA: 0s - loss: 1.3080 - accuracy: 0.5234
# Epoch 38: val_loss did not improve from 1.70230
# 272/272 [==============================] - 66s 217ms/step - loss: 1.3080 - accuracy: 0.5234 - val_loss: 1.7043 - val_accuracy: 0.3419 - lr: 1.0000e-05
# Epoch 39/50
# 272/272 [==============================] - ETA: 0s - loss: 1.3014 - accuracy: 0.5190
# Epoch 39: val_loss did not improve from 1.70230
# 272/272 [==============================] - 67s 222ms/step - loss: 1.3014 - accuracy: 0.5190 - val_loss: 1.7141 - val_accuracy: 0.3419 - lr: 1.0000e-05
# Epoch 40/50
# 272/272 [==============================] - ETA: 0s - loss: 1.2936 - accuracy: 0.5262
# Epoch 40: val_loss improved from 1.70230 to 1.69659, saving model to best_model_VGG16_v2.h5
# 272/272 [==============================] - 65s 216ms/step - loss: 1.2936 - accuracy: 0.5262 - val_loss: 1.6966 - val_accuracy: 0.3479 - lr: 1.0000e-05
# Epoch 41/50
# 272/272 [==============================] - ETA: 0s - loss: 1.2865 - accuracy: 0.5308
# Epoch 41: val_loss did not improve from 1.69659
# 272/272 [==============================] - 65s 215ms/step - loss: 1.2865 - accuracy: 0.5308 - val_loss: 1.7041 - val_accuracy: 0.3459 - lr: 1.0000e-05
# Epoch 42/50
# 272/272 [==============================] - ETA: 0s - loss: 1.2777 - accuracy: 0.5365
# Epoch 42: val_loss improved from 1.69659 to 1.69231, saving model to best_model_VGG16_v2.h5
# 272/272 [==============================] - 65s 215ms/step - loss: 1.2777 - accuracy: 0.5365 - val_loss: 1.6923 - val_accuracy: 0.3424 - lr: 1.0000e-05
# Epoch 43/50
# 272/272 [==============================] - ETA: 0s - loss: 1.2700 - accuracy: 0.5411
# Epoch 43: val_loss did not improve from 1.69231
# 272/272 [==============================] - 65s 215ms/step - loss: 1.2700 - accuracy: 0.5411 - val_loss: 1.6977 - val_accuracy: 0.3394 - lr: 1.0000e-05
# Epoch 44/50
# 272/272 [==============================] - ETA: 0s - loss: 1.2492 - accuracy: 0.5369
# Epoch 44: val_loss improved from 1.69231 to 1.68903, saving model to best_model_VGG16_v2.h5
# 272/272 [==============================] - 65s 215ms/step - loss: 1.2492 - accuracy: 0.5369 - val_loss: 1.6890 - val_accuracy: 0.3469 - lr: 1.0000e-05
# Epoch 45/50
# 272/272 [==============================] - ETA: 0s - loss: 1.2416 - accuracy: 0.5495
# Epoch 45: val_loss did not improve from 1.68903
# 272/272 [==============================] - 64s 214ms/step - loss: 1.2416 - accuracy: 0.5495 - val_loss: 1.6904 - val_accuracy: 0.3414 - lr: 1.0000e-05
# Epoch 46/50
# 272/272 [==============================] - ETA: 0s - loss: 1.2453 - accuracy: 0.5477
# Epoch 46: val_loss did not improve from 1.68903
# 272/272 [==============================] - 64s 213ms/step - loss: 1.2453 - accuracy: 0.5477 - val_loss: 1.6976 - val_accuracy: 0.3358 - lr: 1.0000e-05
# Epoch 47/50
# 272/272 [==============================] - ETA: 0s - loss: 1.2314 - accuracy: 0.5462
# Epoch 47: val_loss improved from 1.68903 to 1.68032, saving model to best_model_VGG16_v2.h5
# 272/272 [==============================] - 65s 215ms/step - loss: 1.2314 - accuracy: 0.5462 - val_loss: 1.6803 - val_accuracy: 0.3449 - lr: 1.0000e-05
# Epoch 48/50
# 272/272 [==============================] - ETA: 0s - loss: 1.2227 - accuracy: 0.5534
# Epoch 48: val_loss improved from 1.68032 to 1.66562, saving model to best_model_VGG16_v2.h5
# 272/272 [==============================] - 65s 215ms/step - loss: 1.2227 - accuracy: 0.5534 - val_loss: 1.6656 - val_accuracy: 0.3565 - lr: 1.0000e-05
# Epoch 49/50
# 272/272 [==============================] - ETA: 0s - loss: 1.2176 - accuracy: 0.5596
# Epoch 49: val_loss did not improve from 1.66562
# 272/272 [==============================] - 64s 212ms/step - loss: 1.2176 - accuracy: 0.5596 - val_loss: 1.6726 - val_accuracy: 0.3514 - lr: 1.0000e-05
# Epoch 50/50
# 272/272 [==============================] - ETA: 0s - loss: 1.2059 - accuracy: 0.5607
# Epoch 50: val_loss did not improve from 1.66562
# 272/272 [==============================] - 64s 211ms/step - loss: 1.2059 - accuracy: 0.5607 - val_loss: 1.6696 - val_accuracy: 0.3524 - lr: 1.0000e-05

# %% [markdown]
# # Evaluating Model

# %% [markdown]
# Model Accuracy Graph Analysis

# %%
fig1 = plt.gcf()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.axis(ymin=0.1,ymax=1)
plt.grid()
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'])
plt.show()

# %% [markdown]
# Model Loss Graph Analysis

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.grid()
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'])
plt.show()

# %% [markdown]
# # Making Predictions

# %%
from tensorflow.keras.models import load_model

# Load the saved model
vgg_16_model = load_model('best_model_VGG16_v2.h5')

# Evaluate the model on the test dataset
evaluation_results = vgg_16_model.evaluate(test_ds)
print("Evaluation results:", evaluation_results)

# Generate predictions
predictions = vgg_16_model.predict(test_ds)

# Get the predicted classes
predicted_classes = np.argmax(predictions, axis=1)

class_labels = ['Normal', 'Diabetes', 'Glaucoma', 'Cataract', 'AMD', 'Hypertension', 'Myopia', 'Other']

# Define the number of images you want to display
num_images_to_display = 9

# Initialize lists to store the images and labels
display_images = []
display_labels = []

# Iterate over the dataset to collect images and labels
for images, labels in test_ds.unbatch().take(num_images_to_display):
    display_images.append(images)
    display_labels.append(labels)

# Now plot the images with predictions and true labels
plt.figure(figsize=(10, 10))
for i, image in enumerate(display_images):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image.numpy().astype("uint8"))
    true_label = class_labels[np.argmax(display_labels[i].numpy())]
    predicted_label = class_labels[predicted_classes[i]]
    plt.title(f"Predicted: {predicted_label}\nTrue: {true_label}")
    plt.axis("off")
plt.show()
# Out:
# 78/78 [==============================] - 12s 152ms/step - loss: 1.6456 - accuracy: 0.3742
# Evaluation results: [1.6456124782562256, 0.37419870495796204]
# 78/78 [==============================] - 12s 149ms/step

# %% [markdown]
# # Predictions Result Evaluation

# %%
from sklearn.metrics import classification_report, balanced_accuracy_score, roc_auc_score

# %% [markdown]
# Classification Report

# %%
# Collect the true labels from the unbatched dataset
true_labels = np.vstack([y.numpy() for _, y in test_ds.unbatch()])

# true_labels should now be a 2-dimensional array, you can verify by printing its shape
print("Shape of true_labels after vstack:", true_labels.shape)

# Convert one-hot encoded labels to class indices
true_classes = np.argmax(true_labels, axis=1)
# Out:
# Shape of true_labels after vstack: (2496, 8)

# %%
class_labels = ['Normal', 'Diabetes', 'Glaucoma', 'Cataract', 'AMD', 'Hypertension', 'Myopia', 'Other diseases']

# Now, the number of predicted classes should match the number of true classes
# Generate the classification report again
report = classification_report(true_classes, predicted_classes, target_names=class_labels, zero_division=0)

print(report)
# Out:
#                 precision    recall  f1-score   support
#
#         Normal       0.60      0.32      0.41      1122
#       Diabetes       0.39      0.36      0.37       632
#       Glaucoma       0.21      0.53      0.30       112
#       Cataract       0.51      0.82      0.63       114
#            AMD       0.30      0.40      0.34       104
#   Hypertension       0.13      0.39      0.19        49
#         Myopia       0.55      0.80      0.65        85
# Other diseases       0.16      0.26      0.20       278
#
#       accuracy                           0.37      2496
#      macro avg       0.35      0.48      0.39      2496
#   weighted avg       0.45      0.37      0.38      2496

# %% [markdown]
# Balanced Accuracy Score

# %%
balanced_accuracy = balanced_accuracy_score(true_classes, predicted_classes)
print('Balanced Accuracy: {:.4f}'.format(balanced_accuracy))
# Out:
# Balanced Accuracy: 0.4831

# %% [markdown]
# Area Under the Reciever Operating Characteristic Curve (AUC-ROC)

# %%
from keras.utils import to_categorical
true_classes_one_hot = to_categorical(true_classes, num_classes=8)

# Calculate ROC AUC for multi-class classification
roc_auc = roc_auc_score(true_classes_one_hot, predictions, average='macro', multi_class='ovo')

print(f'ROC AUC: {roc_auc:.4f}')
# Out:
# ROC AUC: 0.7703

# %% [markdown]
# Confusion Matrix

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Calculate confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)

# Plot confusion matrix
plt.figure(figsize=(10,7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.title('Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()

# %% [markdown]
# # Prediction Evaluation

# %%
class_labels = ['Normal', 'Diabetes', 'Glaucoma', 'Cataract', 'AMD', 'Hypertension', 'Myopia', 'Other']

# Function to get top 3 indices for all predictions
def get_top3_indices(predictions):
    return predictions.argsort()[:, -3:]

# Count the frequency of each class being in the top 3
top3_indices = get_top3_indices(predictions)
class_counts = np.zeros(len(class_labels))

for indices in top3_indices:
    for index in indices:
        class_counts[index] += 1



# Plotting
plt.figure(figsize=(10, 6))
plt.bar(class_labels, class_counts)
plt.xlabel('Class')
plt.ylabel('Frequency in Top 3 Predictions')
plt.title('Frequency of Each Class in Top 3 Predictions Across All Instances')
plt.xticks(rotation=45)
plt.show()
